# %%
pip install langchain-community faiss-cpu
# Out:
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ----------------------------------- ---- 2.1/2.4 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 9.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 12.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 11.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    ------- -------------------------------- 2.9/16.2 MB 15.2 MB/s eta 0:00:01
#    ------------- -------------------------- 5.5/16.2 MB 13.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 9.2/16.2 MB 14.6 MB/s eta 0:00:01
#    -------------------------------- ------- 13.1/16.2 MB 15.5 MB/s eta 0:00:01
#    ---------------------------------------  16.0/16.2 MB 16.5 MB/s eta 0:00:01
# ...

# %%
# !mkdir mongo-ai-agent
# !cd mongo-ai-agent
# !pip install streamlit pymongo langchain langchain-openai python-dotenv
# Out:
# ...
#    ---------------------------------------- 0.0/867.9 kB ? eta -:--:--
#    ---------------------------------------- 867.9/867.9 kB 6.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/557.4 kB ? eta -:--:--
#    ---------------------------------------- 557.4/557.4 kB 2.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/595.1 kB ? eta -:--:--
#    ---------------------------------------- 595.1/595.1 kB 4.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------------------------------- ---- 1.8/2.1 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 8.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 8.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/876.5 kB ? eta -:--:--
#    ---------------------------------------- 876.5/876.5 kB 9.8 MB/s  0:00:00
# ...
#
# ...
